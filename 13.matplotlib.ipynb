# %% [markdown]
# # pip install matplotlib

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(3, 5)

# %%
plt.scatter([3, 4], [5, 6]);

# %%
plt.scatter([3, 4, 9], [5, 6, 7]);

# %%
plt.plot([3, 4, 9], [5, 6, 7]);

# %%
plt.plot([3, 4, 9], [5, 6, 7]);
plt.scatter([3, 4, 9], [5, 6, 7]);

# %%
plt.xlabel("Coordonata x")
plt.ylabel("Coordonata y")

plt.plot([3, 4, 9], [5, 6, 7]);
plt.scatter([3, 4, 9], [5, 6, 7]);

# %%
import numpy as np

# %%
x = np.arange(5, 11)
y = x

# %%
plt.scatter(x, y)

# %%
plt.scatter(x, y)
plt.plot(x, y)

# %%
x = np.arange(5, 11)
print("x=", x)
y = 2 * x + 1
print("y=", y)
# Out:
# x= [ 5  6  7  8  9 10]
# y= [11 13 15 17 19 21]

# %%
plt.scatter(x, y)
plt.plot(x, y)

# %%
x= [ 5,  6,  7,  8,  9, 10]
y= [11, 12, 15, 16, 19, 21]

plt.scatter(x, y)
plt.plot(x, y)
