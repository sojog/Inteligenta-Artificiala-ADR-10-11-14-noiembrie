# %%
def AND_CLASSIC(x1, x2):
    print(f"{x1} and {x2} =  {x1 and x2}")

# %%
AND_CLASSIC(False, False)
AND_CLASSIC(False, True)
AND_CLASSIC(True, False)
AND_CLASSIC(True, True)
# Out:
# False and False =  False
# False and True =  False
# True and False =  False
# True and True =  True

# %%
AND_CLASSIC(0, 0)
AND_CLASSIC(0, 1)
AND_CLASSIC(1, 0)
AND_CLASSIC(1, 1)
# Out:
# 0 and 0 =  0
# 0 and 1 =  0
# 1 and 0 =  0
# 1 and 1 =  1

# %%
def f(x):
    a = 0
    b = 0
    return a * x + b

# %%
def AND_NEURON(x1, x2):
    w1 = 0
    w2 = 0
    b  = 0
    y  = w1 * x1 + w2 * x2 + b         
    print(f"{x1} and {x2} =  {y}")

# %%
AND_NEURON(0, 0)
AND_NEURON(0, 1)
AND_NEURON(1, 0)
AND_NEURON(1, 1)
# Out:
# 0 and 0 =  0
# 0 and 1 =  0
# 1 and 0 =  0
# 1 and 1 =  0

# %%
def AND_NEURON(x1, x2):
    w1 = 1
    w2 = 0
    b  = 0
    y  = w1 * x1 + w2 * x2 + b         
    print(f"{x1} and {x2} =  {y}")

AND_NEURON(0, 0)
AND_NEURON(0, 1)
AND_NEURON(1, 0)
AND_NEURON(1, 1)
# Out:
# 0 and 0 =  0
# 0 and 1 =  0
# 1 and 0 =  1
# 1 and 1 =  1

# %%
def AND_NEURON(x1, x2):
    w1 = 1
    w2 = 1
    b  = 0
    y  = w1 * x1 + w2 * x2 + b         
    print(f"{x1} and {x2} =  {y}")

AND_NEURON(0, 0)
AND_NEURON(0, 1)
AND_NEURON(1, 0)
AND_NEURON(1, 1)
# Out:
# 0 and 0 =  0
# 0 and 1 =  1
# 1 and 0 =  1
# 1 and 1 =  2

# %%
def AND_NEURON(x1, x2):
    w1 = 1
    w2 = 1
    b  = 3
    y  = w1 * x1 + w2 * x2 + b         
    print(f"{x1} and {x2} =  {y}")

AND_NEURON(0, 0)
AND_NEURON(0, 1)
AND_NEURON(1, 0)
AND_NEURON(1, 1)
# Out:
# 0 and 0 =  3
# 0 and 1 =  4
# 1 and 0 =  4
# 1 and 1 =  5

# %%
def AND_NEURON(x1, x2):
    w1 = 1
    w2 = 1
    b  = -3
    y  = w1 * x1 + w2 * x2 + b         
    print(f"{x1} and {x2} =  {y}")

AND_NEURON(0, 0)
AND_NEURON(0, 1)
AND_NEURON(1, 0)
AND_NEURON(1, 1)
# Out:
# 0 and 0 =  -3
# 0 and 1 =  -2
# 1 and 0 =  -2
# 1 and 1 =  -1

# %%
def AND_NEURON(x1, x2):
    w1 = 1321
    w2 = 1312
    b  = 1
    y  = w1 * x1 + w2 * x2 + b         
    print(f"{x1} and {x2} =  {y}")

AND_NEURON(0, 0)
AND_NEURON(0, 1)
AND_NEURON(1, 0)
AND_NEURON(1, 1)
# Out:
# 0 and 0 =  1
# 0 and 1 =  1313
# 1 and 0 =  1322
# 1 and 1 =  2634

# %%
def functie_de_activare(valoare):
    if valoare > 0:
        return 1
    else:
        return 0

def AND_NEURON(x1, x2):
    w1 = 1321
    w2 = 1312
    b  = 1
    y  = w1 * x1 + w2 * x2 + b         
    print(f"{x1} and {x2} =  {y}")

AND_NEURON(0, 0)
AND_NEURON(0, 1)
AND_NEURON(1, 0)
AND_NEURON(1, 1)
# Out:
# 0 and 0 =  1
# 0 and 1 =  1313
# 1 and 0 =  1322
# 1 and 1 =  2634

# %%
def functie_de_activare(valoare):
    if valoare > 0:
        return 1
    else:
        return 0

def AND_NEURON(x1, x2):
    w1 = 1321
    w2 = -1312
    b  = 1
    y  = functie_de_activare(w1 * x1 + w2 * x2 + b)
    print(f"{x1} and {x2} =  {y}")

AND_NEURON(0, 0)
AND_NEURON(0, 1)
AND_NEURON(1, 0)
AND_NEURON(1, 1)
# Out:
# 0 and 0 =  1
# 0 and 1 =  0
# 1 and 0 =  1
# 1 and 1 =  1

# %%
def functie_de_activare(valoare):
    if valoare > 0:
        return 1
    else:
        return 0

def AND_NEURON(x1, x2):
    w1 = 1
    w2 = 1
    b  = -1.5
    y  = functie_de_activare(w1 * x1 + w2 * x2 + b)
    print(f"{x1} and {x2} =  {y}")

AND_NEURON(0, 0)
AND_NEURON(0, 1)
AND_NEURON(1, 0)
AND_NEURON(1, 1)
# Out:
# 0 and 0 =  0
# 0 and 1 =  0
# 1 and 0 =  0
# 1 and 1 =  1

# %%
def OR_CLASSIC(x1, x2):
    print(f"{x1} or {x2} =  {x1 or x2}")

# %%
OR_CLASSIC(0, 0)
OR_CLASSIC(0, 1)
OR_CLASSIC(1, 0)
OR_CLASSIC(1, 1)
# Out:
# 0 or 0 =  0
# 0 or 1 =  1
# 1 or 0 =  1
# 1 or 1 =  1

# %%
def functie_de_activare(valoare):
    if valoare > 0:
        return 1
    else:
        return 0

def OR_NEURON(x1, x2):
    w1 = 1
    w2 = 1
    b  = -0.5
    y  = functie_de_activare(w1 * x1 + w2 * x2 + b)
    print(f"{x1} and {x2} =  {y}")

OR_NEURON(0, 0)
OR_NEURON(0, 1)
OR_NEURON(1, 0)
OR_NEURON(1, 1)
# Out:
# 0 and 0 =  0
# 0 and 1 =  1
# 1 and 0 =  1
# 1 and 1 =  1
