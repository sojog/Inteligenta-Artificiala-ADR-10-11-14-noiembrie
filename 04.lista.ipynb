# %% [markdown]
# # Lista este un tip de date compus

# %%
o_lista = [ 1, 2, 3, 4, 5, 6, 7 ]
print(o_lista, type(o_lista))
# Out:
# [1, 2, 3, 4, 5, 6, 7] <class 'list'>

# %% [markdown]
# # Pentru a numara elementele

# %%
# Numar valorile
len(o_lista)
# Out:
# 7

# %% [markdown]
# # Pentru a lua un anumit element. de pe o pozitie anume

# %%
o_lista[0]
# Out:
# 1

# %%
o_lista[6]
# Out:
# 7

# %%
o_lista = [ 1, 2, 3, 4, 5, 6, 7 ]
o_lista[7]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[5], line 2
#       1 o_lista = [ 1, 2, 3, 4, 5, 6, 7 ]
# ----> 2 o_lista[7]
#
# IndexError: list index out of range

# %%
o_lista = [ 1, 2, 3, 4, 5, 6, 7 ]
o_lista[-1]
# Out:
# 7

# %%
o_lista = [ 1, 2, 3, 4, 5, 6, 7 ]
o_lista[-2]
# Out:
# 6

# %%
o_lista = [ 1, 2, 3, 4, 5, 6, 7 ]
o_lista[-7]
# Out:
# 1

# %%
x = 10
x
# Out:
# 10

# %%
x = 10
print(x)
# Out:
# 10

# %%
o_lista = [ 1, 2, 3, 4, 5, 6, 7 ]
o_lista[-7]

# %% [markdown]
# # Lista poate avea elemente de tipuri diferite

# %%
o_lista = [ 1, 2, 3, 4, 5, 6, 7, 38.93, "hello" ]
o_lista[-1]
# Out:
# 'hello'

# %%
o_lista = [ 1, 2, 3, 4, 5, 6, 7, 38.93, "hello", [20, 30] ]
print("len", len(o_lista))
# Out:
# len 10

# %%
o_lista = [ 1, 2, 3, 4, 5, 6, 7, 38.93, "hello", [20, 30] ]
o_lista.append(300)
o_lista
# Out:
# [1, 2, 3, 4, 5, 6, 7, 38.93, 'hello', [20, 30], 300]

# %%
o_lista.clear()

# %%
o_lista
# Out:
# []

# %%
o_lista = [ 1,  38.93, "hello", [20, 30], 3000, 6600  ]
o_lista
# Out:
# [1, 38.93, 'hello', [20, 30], 3000, 6600]

# %%
o_lista.pop()
o_lista
# Out:
# [1, 38.93, 'hello', [20, 30], 3000]

# %%
o_lista.pop(0)
o_lista
# Out:
# [38.93, 'hello', [20, 30], 3000]

# %% [markdown]
# # Iteratie poate fi doar printr-o colectie (ex: lista)

# %%
o_lista = [ 1,  38.93, "hello", [20, 30], 3000, 6600  ]
for i in o_lista:      # nu exista iteratie de forma for(int i =0; i<o_lista.size();i++):
    print("i=", i)
# Out:
# i= 1
# i= 38.93
# i= hello
# i= [20, 30]
# i= 3000
# i= 6600
