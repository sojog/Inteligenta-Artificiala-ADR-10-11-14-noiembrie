# %%
import requests

# %%
response = requests.get("https://www.cursbnr.ro/")
response
# Out:
# <Response [200]>

# %%
response.content
# Out:
# b'<!DOCTYPE html>\n<html lang="ro">\n<head>\n<meta http-equiv="Content-Type" content="text/html; charset=utf-8" />\n<meta name="viewport" content="width=device-width, initial-scale=1, maximum-scale=1">\n<title>Curs BNR, Curs valutar online, Curs euro</title>\n<meta name="Description" content="Afla cursul BNR de azi si evolutia din ultimele zile. Pentru schimb valutar foloseste convertorul rapid si urmareste online cursul valutar al bancilor romanesti" />\n<meta name="Keywords" content="curs bnr, curs valutar, curs euro, convertor valutar, cotatii valutare, grafic evolutie valute, arhiva curs bnr" />\n<meta name="Owner" content="CursBnr" />\n<meta name="Copyright" content="2025 CursBnr" />\n<meta name="Rating" content="General" />\n<meta name="Publisher" content="CursBnr, www.cursbnr.ro" />\n<meta name="Author" content="CursBnr, www.cursbnr.ro" />\n<meta name="Robots" content="index,follow" />\n<script type="text/javascript">\n\tvar stlSetCookie = function (name, value, days) {\n\t\tvar d = new Date();\n\t\td.setTime(d.getTime() + (days * 24 * 60 * 60 * 1000));\n\t\tvar expires = "expires=" + d.toUTCString();\n\t\tdocument.cookie = name + "=" + value + "; " + expires + "; path=/";\n\t};\n\tvar stlGetCookie = function (cookie_name) {\n\t\tvar name = cookie_name + "=";\n\t\tvar decodedCookie = decodeURIComponent(document.cookie);\n\t\tvar ca = decodedCookie.split(\';\');\n\t\tfor(var i = 0; i <ca.length; i++) {\n\t\t\tvar c = ca[i];\n\t\t\twhile (c.charAt(0) == \' \') {\n\t\t\t\tc = c.substring(1);\n\t\t\t}\n\t\t\tif (c.indexOf(name) == 0) {\n\t\t\t\treturn c.substring(name.length, c.length);\n\t\t\t}\n\t\t}\n\t\treturn null;\n\t}\n</script>\n<link rel="canonical" href="https://www.cursbnr.ro/" />\n<link rel="apple-touch-icon" sizes="180x180" href="/apple-touch-icon.png">\n<link rel="icon" type="image/png" href="/favicon-32x32.png" sizes="32x32">\n<link rel="icon" type="image/png" href="/favicon-16x16.png" sizes="16x16">\n\n<link rel="mask-icon" href="/safari-pinned-tab.svg" color="#5bbad5">\n<meta name="theme-color" content="#ffffff">\n\n\n<!--<link rel="stylesheet" href="css/bootstrap.min.css">-->\n<link href="https://maxcdn.bootstrapcdn.com/bootstrap/3.3.6/css/bootstrap.min.css" rel="stylesheet" integrity="sha384-1q8mTJOASx8j1Au+a5WDVnPi2lkFfwwEAa8hDDdjZlpLegxhjVME1fgjWPGmkzs7" crossorigin="anonymous">\n\n\n<link rel="stylesheet" type="text/css" href="css/main.min.css?v=1.3.7">\n\n<!--[if lt IE 9]><script src="https://cdnjs.cloudflare.com/ajax/libs/html5shiv/3.7.3/html5shiv.js"></script><![endif]-->\n\n<meta name="google-site-verification" content="hI-BuXuc-_r6MXHc8Ha0LSBL03Sp1rtpJRNfZolSLng" />\n\n<script async src="https://pagead2.googlesyndication.com/pagead/js/adsbygoogle.js?client=ca-pub-8531929493333637" crossorigin="anonymous"></script>\n<script async src="https://fundingchoicesmessages.google.com/i/pub-8531929493333637?ers=1" nonce="vZQ_IRWKiYnke7gqvFWYHw"></script><script nonce="vZQ_IRWKiYnke7gqvFWYHw">(function() {function signalGooglefcPresent() {if (!window.frames[\'googlefcPresent\']) {if (document.body) {const iframe = document.createElement(\'iframe\'); iframe.style = \'width: 0; height: 0; border: none; z-index: -1000; left: -1000px; top: -1000px;\'; iframe.style.display = \'none\'; iframe.name = \'googlefcPresent\'; document.body.appendChild(iframe);} else {setTimeout(signalGooglefcPresent, 0);}}}signalGooglefcPresent();})();</script>\n<meta property="og:url"           content="https://www.cursbnr.ro/" />\n<meta property="og:type"          content="website" />\n<meta property="og:title"         content="Curs BNR, Curs valutar online, Curs euro" />\n<meta property="og:description"   content="Afla cursul BNR de azi si evolutia din ultimele zile. Pentru schimb valutar foloseste convertorul rapid si urmareste online cursul valutar al bancilor romanesti" />\n<meta property="og:image"         content="https://www.cursbnr.ro/images2/logo-sageata.png" />\n\n</head>\n<body>\n\n<!-- <script src="js/jquery-3.1.1.min.js"> ...

# %%
OLLAMA_VERSION_URL = "http://localhost:11434/api/version"

# %%
response = requests.get(OLLAMA_VERSION_URL)
response.content
# Out:
# b'{"version":"0.12.10"}'

# %%
OLLAMA_URL = "http://localhost:11434/api/generate"

# %%
payload = {
    "model" : "gemma3:270m",
    "prompt" : "Ce tipuri de termopane exista?",
    "stream" : False
}

# %%
response = requests.post(OLLAMA_URL, json=payload)
print(response.content)
# Out:
# b'{"model":"gemma3:270m","created_at":"2025-11-11T11:12:28.203098Z","response":"Termopane este un material de termoplastice care areaz\xc4\x83 o structur\xc4\x83 de urechi cu o structur\xc4\x83 de urechi cu o structur\xc4\x83 de urechi, o perioad\xc4\x83 de izolare. Aceasta face ca termopane s\xc4\x83 fie foarte eficiente \xc3\xaen termocultur\xc4\x83.\\n","done":true,"done_reason":"stop","context":[105,2364,107,24718,6508,7149,569,1941,650,1629,145707,236881,106,107,105,4368,107,10960,650,1629,4462,723,2561,569,1941,52372,762,2065,659,43019,512,2456,92138,569,47365,6411,2757,512,2456,92138,569,47365,6411,2757,512,2456,92138,569,47365,6411,236764,512,102706,177908,569,6947,30258,236761,39192,7478,3392,2146,1941,650,1629,13338,48405,62162,96196,7840,1941,629,52005,237106,236761,107],"total_duration":522051042,"load_duration":104394958,"prompt_eval_count":18,"prompt_eval_duration":15300917,"eval_count":60,"eval_duration":378470208}'

# %%
response.json()["response"]
# Out:
# 'Termopane este un material de termoplastice care arează o structură de urechi cu o structură de urechi cu o structură de urechi, o perioadă de izolare. Aceasta face ca termopane să fie foarte eficiente în termocultură.\n'
