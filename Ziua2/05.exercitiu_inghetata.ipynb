# %% [markdown]
# # pip install pandas

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv("date_inghetata.csv")
df
# Out:
#      temperatura  vanzari      luna zi_saptamana
# 0              8       25  ianuarie         luni
# 1             10       35  ianuarie        marti
# 2             12       45  ianuarie     miercuri
# 3             15       55  ianuarie          joi
# 4             18       75  ianuarie       vineri
# ..           ...      ...       ...          ...
# 233           33      168       mai     miercuri
# 234           35      182       mai          joi
# 235           37      195       mai       vineri
# 236           39      208       mai      sambata
# 237           41      222       mai    duminica
#
# [238 rows x 4 columns]

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df[["temperatura"]]
# Out:
#      temperatura
# 0              8
# 1             10
# 2             12
# 3             15
# 4             18
# ..           ...
# 233           33
# 234           35
# 235           37
# 236           39
# 237           41
#
# [238 rows x 1 columns]

# %%
np.array(df[["temperatura"]])
# Out:
# array([[ 8],
#        [10],
#        [12],
#        [15],
#        [18],
#        [20],
#        [22],
#        [ 9],
#        [11],
#        [13],
#        [16],
#        [19],
#        [21],
#        [23],
#        [14],
#        [16],
#        [18],
#        [20],
#        [22],
#        [24],
#        [26],
#        [15],
#        [17],
#        [19],
#        [21],
#        [23],
#        [25],
#        [27],
#        [18],
#        [20],
#        [22],
#        [24],
#        [26],
#        [28],
#        [30],
#        [19],
#        [21],
#        [23],
#        [25],
#        [27],
#        [29],
#        [31],
#        [22],
#        [24],
#        [26],
#        [28],
#        [30],
#        [32],
#        [34],
#        [23],
#        [25],
#        [27],
#        [29],
#        [31],
#        [33],
#        [35],
#        [26],
#        [28],
#        [30],
#        [32],
#        [34],
#        [36],
#        [38],
#        [27],
#        [29],
#        [31],
#        [33],
#        [35],
#        [37],
#        [39],
#        [30],
#        [32],
#        [34],
#        [36],
#        [38],
#        [40],
#        [42],
#        [31],
#        [33],
#        [35],
#        [37],
#        [39],
#        [41],
#        [43],
#        [34],
#        [36],
#        [38],
#        [40],
#        [42],
#        [44],
#        [45],
#        [35],
#        [37],
#        [39],
#        [41],
#        [43],
#        [45],
#        [44],
#        [38],
#        [40],
#        [42],
#        [44],
#        [45],
#        [43],
#        [41],
#        [39],
#        [41],
#        [43],
#        [45],
#        [44],
#        [42],
#        [40],
#        [35],
#        [37],
#        [39],
#        [41],
#        [43],
#        [40],
#        [38],
#        [36],
#        [38],
#        [40],
#        [42],
#        [39],
#        [37],
#        [35],
#        [30],
#        [32],
#        [34],
#        [36],
#        [38],
#        [35],
#        [32],
#        [31],
#        [33],
#        [35],
#        [32],
#        [29],
#        [27],
#        [25],
#        [24],
#        [26],
#        [28],
#        [30],
#        [27],
#        [24],
#        [22],
#        [25],
#        [27],
#        [29],
#        [26],
#        [23],
#        [21],
#        [19],
#        [18],
#        [20],
#        [22],
#        [24],
#        [21],
#        [18],
#        [16],
#        [19],
#        [21],
#        [23],
#        [20],
#        [17],
#        [15],
#        [13],
#        [16],
#        [18],
#        [20],
#        [22],
#        [24],
#        [26],
#        [28],
#        [17],
#        [19],
#        [21],
#        [23],
#        [25],
#        [27],
#        [29],
#        [12],
#        [14],
#        [16],
#        [18],
#        [20],
#        [22],
#        [24],
#        [13],
#        [15],
#        [17],
#        [19],
#        [21],
#        [23],
#        [25],
#        [20],
#        [22],
#        [24],
#        [26],
#        [28],
#        [30],
#        [32],
#        [21],
#        [23],
#        [25],
#        [27],
#        [29],
#        [31],
#        [33],
#        [25],
#        [27],
#        [29],
#        [31],
#        [33],
#        [35],
#        [37],
#        [26],
#        [28],
#        [30],
#        [32],
#        [34],
#        [36],
#        [38],
#        [28],
#        [30],
#        [32],
#        [34],
#        [36],
#        [38],
#        [40],
#        [29],
#        [31],
#        [33],
#        [35],
#        [37],
#        [39],
#        [41]])

# %%
# Dataset-ul conține temperatura zilnică (°C) și vânzările de înghețată (unități) pentru o gelaterie din București pe parcursul unui an întreg, cu peste 200 de înregistrări.

# %%
temperatura = df[["temperatura"]]
vanzari = df[["vanzari"]]

# %%
#  1. Trebuie creat un scatter plot pentru a vizualiza relația dintre temperatură și vânzări.
plt.scatter(temperatura, vanzari)

# %%
# 2. Trebuie să separi datele în variabila independentă (X) și variabila dependentă (y). Variabila independentă este temperatura, iar variabila dependentă este numărul de vânzări.

plt.scatter(temperatura, vanzari)
plt.xlabel("temperatura");
plt.ylabel("vanzari");

# %%
from sklearn.model_selection import train_test_split

# %%
# 3. Împarte datele în seturi de antrenament și testare. Vei folosi 78% din date pentru antrenament și 22% pentru testare.

temp_train, temp_test, vanz_train, vanz_test = train_test_split(temperatura, vanzari, test_size=0.22)

# %%
# 4. Creează un model de regresie și antrenează-l pe datele de antrenament.

from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(temp_train, vanz_train)
# Out:
# LinearRegression()

# %%
# 5. Folosește modelul pentru a prezice vânzările pentru temperaturi noi pe care nu le-ai văzut înainte.
vanz_prezise = model.predict(temp_test)

# %%
linear_model_score =model.score(temp_test, vanz_test)
linear_model_score
# Out:
# 0.9862810568485325

# %%
# 6. Compară scorul cu a unui alt model

from sklearn.neighbors import KNeighborsRegressor
knn_model = KNeighborsRegressor()
knn_model.fit(temp_train, vanz_train)
# Out:
# KNeighborsRegressor()

# %%
knn_model_score = knn_model.score(temp_test, vanz_test)
knn_model_score
# Out:
# 0.9917546747682481
