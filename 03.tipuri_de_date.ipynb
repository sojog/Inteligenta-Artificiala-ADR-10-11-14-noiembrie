# %%
## INTEGER
x = 2
print(x, type(x))  # int
# Out:
# 2 <class 'int'>

# %%
## FLOATING NUMBER
x = 2.032
print(x, type(x))  # float
# Out:
# 2.032 <class 'float'>

# %%
## BOOLEAN
x = True
print(x, type(x))  # bool
# Out:
# True <class 'bool'>

# %%
## STRING
x = "hello"
print(x, type(x))  # str
# Out:
# hello <class 'str'>
