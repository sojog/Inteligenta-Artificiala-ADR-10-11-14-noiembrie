# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.neighbors import KNeighborsClassifier

# %%
date = {
    "Alina": [60, 165, True],
    "Bogdan": [72, 183, False],
    "Ciprian": [69, 178, False],
    "Diana": [55, 152, True],
    "Elena": [58, 168, True],
    "Andrei": [80, 185, False],
    "Mihai": [75, 177, False],
    "Irina": [62, 170, True],
    "Florin": [90, 190, False],
    "Maria": [53, 160, True],
    "Vlad": [70, 175, False],
    "Ioana": [50, 155, True],
    "Radu": [68, 172, False],
    "Ana": [59, 162, True],
    "George": [85, 182, False],
    "Larisa": [61, 167, True],
    "Stefan": [78, 180, False],
    "Bianca": [56, 158, True],
    "Paul": [74, 176, False],
    "Oana": [54, 163, True],
    "Cosmin": [82, 188, False],
    "Teodora": [57, 159, True],
    "Ionut": [76, 181, False],
    "Gabriela": [60, 164, True]
}

# %%
pd.DataFrame(date)
# Out:
#   Alina Bogdan Ciprian Diana Elena Andrei  Mihai Irina Florin Maria  ...  \
# 0    60     72      69    55    58     80     75    62     90    53  ...
# 1   165    183     178   152   168    185    177   170    190   160  ...
# 2  True  False   False  True  True  False  False  True  False  True  ...
#
#   George Larisa Stefan Bianca   Paul  Oana Cosmin Teodora  Ionut Gabriela
# 0     85     61     78     56     74    54     82      57     76       60
# 1    182    167    180    158    176   163    188     159    181      164
# 2  False   True  False   True  False  True  False    True  False     True
#
# [3 rows x 24 columns]

# %%
df = pd.DataFrame(date.values(), columns=["Greutate", "Inaltime", "Voce"], index=date.keys())
df.head()
# Out:
#          Greutate  Inaltime   Voce
# Alina          60       165   True
# Bogdan         72       183  False
# Ciprian        69       178  False
# Diana          55       152   True
# Elena          58       168   True

# %%
from sklearn.preprocessing   import LabelEncoder

# %%
df["Voce"] = LabelEncoder().fit_transform(df["Voce"])
df
# Out:
#           Greutate  Inaltime  Voce
# Alina           60       165     1
# Bogdan          72       183     0
# Ciprian         69       178     0
# Diana           55       152     1
# Elena           58       168     1
# Andrei          80       185     0
# Mihai           75       177     0
# Irina           62       170     1
# Florin          90       190     0
# Maria           53       160     1
# Vlad            70       175     0
# Ioana           50       155     1
# Radu            68       172     0
# Ana             59       162     1
# George          85       182     0
# Larisa          61       167     1
# Stefan          78       180     0
# Bianca          56       158     1
# Paul            74       176     0
# Oana            54       163     1
# Cosmin          82       188     0
# Teodora         57       159     1
# Ionut           76       181     0
# Gabriela        60       164     1

# %%
plt.scatter(df["Greutate"], df["Inaltime"]);
plt.xlabel("Greutate");
plt.ylabel("Inaltime");

# %%
plt.scatter(df["Greutate"], df["Inaltime"], c=df["Voce"]);
plt.xlabel("Greutate");
plt.ylabel("Inaltime");

# %%
df.describe()
# Out:
#         Greutate    Inaltime       Voce
# count  24.000000   24.000000  24.000000
# mean   66.833333  171.250000   0.500000
# std    11.273928   10.883773   0.510754
# min    50.000000  152.000000   0.000000
# 25%    57.750000  162.750000   0.000000
# 50%    65.000000  171.000000   0.500000
# 75%    75.250000  180.250000   1.000000
# max    90.000000  190.000000   1.000000

# %%
from sklearn.preprocessing import StandardScaler

# %%
standard_scaler = StandardScaler()
standard_scaler
# Out:
# StandardScaler()

# %%
df.head(2)
# Out:
#         Greutate  Inaltime  Voce
# Alina         60       165     1
# Bogdan        72       183     0

# %%
scaled_df = pd.DataFrame(standard_scaler.fit_transform(df[["Greutate", "Inaltime"]]), columns=["Greutate", "Inaltime"])
scaled_df
# Out:
#     Greutate  Inaltime
# 0  -0.619155 -0.586600
# 1   0.468141  1.102808
# 2   0.196317  0.633528
# 3  -1.072194 -1.806729
# 4  -0.800370 -0.305032
# 5   1.193005  1.290521
# 6   0.739965  0.539672
# 7  -0.437939 -0.117320
# 8   2.099085  1.759801
# 9  -1.253410 -1.055880
# 10  0.286925  0.351960
# 11 -1.525234 -1.525161
# 12  0.105709  0.070392
# 13 -0.709763 -0.868168
# 14  1.646045  1.008952
# 15 -0.528547 -0.398888
# 16  1.011789  0.821240
# 17 -0.981586 -1.243592
# 18  0.649357  0.445816
# 19 -1.162802 -0.774312
# 20  1.374221  1.572089
# 21 -0.890978 -1.149736
# 22  0.830573  0.915096
# 23 -0.619155 -0.680456

# %%
df
# Out:
#           Greutate  Inaltime  Voce
# Alina           60       165     1
# Bogdan          72       183     0
# Ciprian         69       178     0
# Diana           55       152     1
# Elena           58       168     1
# Andrei          80       185     0
# Mihai           75       177     0
# Irina           62       170     1
# Florin          90       190     0
# Maria           53       160     1
# Vlad            70       175     0
# Ioana           50       155     1
# Radu            68       172     0
# Ana             59       162     1
# George          85       182     0
# Larisa          61       167     1
# Stefan          78       180     0
# Bianca          56       158     1
# Paul            74       176     0
# Oana            54       163     1
# Cosmin          82       188     0
# Teodora         57       159     1
# Ionut           76       181     0
# Gabriela        60       164     1

# %%
df.describe()
# Out:
#         Greutate    Inaltime       Voce
# count  24.000000   24.000000  24.000000
# mean   66.833333  171.250000   0.500000
# std    11.273928   10.883773   0.510754
# min    50.000000  152.000000   0.000000
# 25%    57.750000  162.750000   0.000000
# 50%    65.000000  171.000000   0.500000
# 75%    75.250000  180.250000   1.000000
# max    90.000000  190.000000   1.000000
